# %% [markdown]
# # Pandas

# %%
# it is one of the most powerful library which we will encounter
# different kind of a dataset based operation
# pandas, is where we can deal with different file, Csv file, excel sheet, abro file, parke file, rc file, orc file

# %%
# Pandas helps  in read write, manipulate everything kind of an operation in an easisest possible way
# From the first day to the last day we end up using the libraries such as pandas, numpy, plotly, cufflinks etc etc

# %%
#what is pandas, how i will be able to use pandas, what are all the features i will be able to see in pandas

# %%
#Download data from here : https://github.com/codeforamerica/ohana-api, download zip

# %%
import pandas as pd

# %%
# %ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 408C-821B
#
#  Directory of C:\Users\ashish\Desktop\Ineuron
#
# 05/19/2022  06:43 PM    <DIR>          .
# 05/19/2022  06:43 PM    <DIR>          ..
# 04/07/2022  03:12 PM    <DIR>          .idea
# 05/19/2022  05:22 PM    <DIR>          .ipynb_checkpoints
# 04/10/2022  03:11 PM    <DIR>          __pycache__
# 04/15/2022  09:22 PM                17 abc.txt
# 04/10/2022  01:57 PM                 0 Dict.log
# 05/10/2022  10:32 PM            11,903 glass.data
# 05/18/2022  02:30 PM             8,192 ineuron.db
# 05/17/2022  11:35 AM            12,288 jobdb.db
# 04/15/2022  10:07 PM           197,467 list.log
# 04/05/2022  03:49 PM                 0 Modules , Modular coding.txt
# 04/07/2022  01:01 AM    <DIR>          My Directory
# 04/07/2022  12:11 AM               237 my_module.py
# 04/10/2022  03:11 PM             6,829 mydict.py
# 04/05/2022  02:19 PM               865 Notepad++.lnk
# ...

# %%
pd.read_csv('sample_test.csv')
# Out:
#         name                      emailid    address  pincode       sirname
# 0     Ashish  ashishroyofficial@gmail.com  Bangalore   560090           roy
# 1  sudhanshu        sskumar9876@gmail.com     Mumbai   560085         kumar
# 2      krish              krish@gmail.com      Delhi   560034          naik
# 3    ineuron           ineuron@ineuron.ai    Chennai    42343  intelligence

# %%
pd.read_csv("C:/Users/ashish/Downloads/ohana-api-master/data/sample-csv/locations.csv")
# Out:
#     id  organization_id                                      accessibility  \
# 0    1                1       disabled_parking, ramp, restroom, wheelchair
# 1    2                1                                         wheelchair
# 2    3                1                                                NaN
# 3    4                1                                         wheelchair
# 4    5                1                                         wheelchair
# 5    6                2                       disabled_parking, wheelchair
# 6    7                2       ramp, restroom, disabled_parking, wheelchair
# 7    8                2                                                NaN
# 8    9                3                         ramp, restroom, wheelchair
# 9   10                3  elevator, tape_braille, ramp, restroom, disabl...
# 10  11                3                                               ramp
# ...

# %%
df = pd.read_csv(r"C:/Users/ashish/Downloads/ohana-api-master/data/sample-csv/services.csv")

# %%
df = pd.read_csv(r"C:/Users/ashish/Downloads/ohana-api-master/data/sample-csv/taxonomy.csv")

# %%
# How is it considering the rows and columns automatically? how is it doing that
# In pandas it always tries to consider the first row as a column name
# There is a provision by which we can avoid taking column name
# By default it gives row indexes
# it is generated by pandas itself
# it is auto populated
# pandas is used to do some sort of a manipulation in respect to a structured data
# When you have unstructured data we cannot use pandas at all

# For now dealing with unstructured data is 5 unstructured and 5 structured data
# This is nothing but a dataframe, it is also called as a tabular structure
# type  = dataframe

# %%
df
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # There are 2 type of a datatype, 1 is a dataframe, another is called as series

# %%
#what happens when we dont have column in the very first row, will we consider that as a column name? no

# %%
#so what do we do?

# %%
#header by default is infer so what we can do is as below as none
df = pd.read_csv('C:/Users/ashish/Downloads/ohana-api-master/data/sample-csv/taxonomy.csv',header=None)

# %%
df
# Out:
#                0                             1          2  \
# 0    taxonomy_id                          name  parent_id
# 1            101                     Emergency        NaN
# 2         101-01             Disaster Response        101
# 3         101-02                Emergency Cash        101
# 4      101-02-01             Help Pay for Food     101-02
# ..           ...                           ...        ...
# 286    111-01-07              Workplace Rights     111-01
# 287       111-02                     Mediation        111
# 288       111-03                        Notary        111
# 289       111-04                Representation        111
# 290       111-05  Translation & Interpretation        111
#
#                         3
# 0             parent_name
# 1                     NaN
# 2               Emergency
# 3               Emergency
# 4          Emergency Cash
# ..                    ...
# 286  Advocacy & Legal Aid
# 287                 Legal
# ...

# %%
# it will default column name as numbers, 0,1,2,3,4,5

# %%
#Giving my own column name
pd.read_csv("C:/Users/ashish/Downloads/ohana-api-master/data/sample-csv/taxonomy.csv", names= ["a","b","c","d"])
# Out:
#                a                             b          c  \
# 0    taxonomy_id                          name  parent_id
# 1            101                     Emergency        NaN
# 2         101-01             Disaster Response        101
# 3         101-02                Emergency Cash        101
# 4      101-02-01             Help Pay for Food     101-02
# ..           ...                           ...        ...
# 286    111-01-07              Workplace Rights     111-01
# 287       111-02                     Mediation        111
# 288       111-03                        Notary        111
# 289       111-04                Representation        111
# 290       111-05  Translation & Interpretation        111
#
#                         d
# 0             parent_name
# 1                     NaN
# 2               Emergency
# 3               Emergency
# 4          Emergency Cash
# ..                    ...
# 286  Advocacy & Legal Aid
# 287                 Legal
# ...

# %%
#suppose we have created an extra column,will take it ? yes it will take it and give NaN values for that extra column
#Not A Number
pd.read_csv("C:/Users/ashish/Downloads/ohana-api-master/data/sample-csv/taxonomy.csv", names= ["a","b","c","d","e"])
# Out:
#                a                             b          c  \
# 0    taxonomy_id                          name  parent_id
# 1            101                     Emergency        NaN
# 2         101-01             Disaster Response        101
# 3         101-02                Emergency Cash        101
# 4      101-02-01             Help Pay for Food     101-02
# ..           ...                           ...        ...
# 286    111-01-07              Workplace Rights     111-01
# 287       111-02                     Mediation        111
# 288       111-03                        Notary        111
# 289       111-04                Representation        111
# 290       111-05  Translation & Interpretation        111
#
#                         d   e
# 0             parent_name NaN
# 1                     NaN NaN
# 2               Emergency NaN
# 3               Emergency NaN
# 4          Emergency Cash NaN
# ..                    ...  ..
# 286  Advocacy & Legal Aid NaN
# ...

# %%
#suppose we have created an less column,will take it ? yes it will take it and take the very first column name as row indexes
# Execute this to know

pd.read_csv("C:/Users/ashish/Downloads/ohana-api-master/data/sample-csv/taxonomy.csv", names= ["a","b","c"])
# Out:
#                                         a          b                     c
# taxonomy_id                          name  parent_id           parent_name
# 101                             Emergency        NaN                   NaN
# 101-01                  Disaster Response        101             Emergency
# 101-02                     Emergency Cash        101             Emergency
# 101-02-01               Help Pay for Food     101-02        Emergency Cash
# ...                                   ...        ...                   ...
# 111-01-07                Workplace Rights     111-01  Advocacy & Legal Aid
# 111-02                          Mediation        111                 Legal
# 111-03                             Notary        111                 Legal
# 111-04                     Representation        111                 Legal
# 111-05       Translation & Interpretation        111                 Legal
#
# [291 rows x 3 columns]

# %%
#suppose we have created an less column,will take it ? yes it will take it and take the very first column name as row indexes
# Execute this to know, This will consider 2 columns as row indexes\
# There is a lot of operational significance which wee will learn in terms of row indexes and column indexes

pd.read_csv("C:/Users/ashish/Downloads/ohana-api-master/data/sample-csv/taxonomy.csv", names= ["a","b"])
# Out:
#                                                   a                     b
# taxonomy_id name                          parent_id           parent_name
# 101         Emergency                           NaN                   NaN
# 101-01      Disaster Response                   101             Emergency
# 101-02      Emergency Cash                      101             Emergency
# 101-02-01   Help Pay for Food                101-02        Emergency Cash
# ...                                             ...                   ...
# 111-01-07   Workplace Rights                 111-01  Advocacy & Legal Aid
# 111-02      Mediation                           111                 Legal
# 111-03      Notary                              111                 Legal
# 111-04      Representation                      111                 Legal
# 111-05      Translation & Interpretation        111                 Legal
#
# [291 rows x 2 columns]

# %%
# here we can use sep as delimeter to seperate values
df = pd.read_csv('sample_test.csv',sep="@")

# %%
df
# Out:
#                           name| emailid|address|pincode|sirname
# Ashish|ashishroyofficial         gmail.com|Bangalore|560090|roy
# sudhanshu|sskumar9876             gmail.com|Mumbai|560085|kumar
# krish|krish|gmail.com                         Delhi|560034|naik
# ineuron|ineuron           ineuron.ai|Chennai|42343|intelligence

# %%
# Maybe we dont want a specific row when importing the data, how do we do it?
df = pd.read_csv('sample_test.csv',sep="|",skiprows=[1,3])

# %%
df
# Out:
#         name                emailid  address  pincode       sirname
# 0  sudhanshu  sskumar9876@gmail.com   Mumbai   560085         kumar
# 1    ineuron     ineuron@ineuron.ai  Chennai    42343  intelligence

# %%
df1 = pd.read_csv('sample_test.csv',sep="|")

# %%
df1
# Out:
#         name                      emailid          address  pincode  \
# 0     Ashish  ashishroyofficial@gmail.com        Bangalore   560090
# 1  sudhanshu        sskumar9876@gmail.com           Mumbai   560085
# 2      krish                        krish  gmail.com@Delhi   560034
# 3    ineuron           ineuron@ineuron.ai          Chennai    42343
#
#         sirname
# 0           roy
# 1         kumar
# 2          naik
# 3  intelligence

# %%
df = pd.read_csv('C:/Users/ashish/Downloads/ohana-api-master/data/sample-csv/services.csv')

# %%
# Datatype
# String = object
# int = int
# float = float
df.dtypes
# Out:
# id                           int64
# location_id                  int64
# program_id                 float64
# accepted_payments           object
# alternate_name              object
# application_process         object
# audience                    object
# description                 object
# eligibility                 object
# email                       object
# fees                        object
# funding_sources             object
# interpretation_services     object
# keywords                    object
# languages                   object
# name                        object
# required_documents          object
# service_areas               object
# status                      object
# wait_time                   object
# website                     object
# taxonomy_ids                object
# dtype: object

# %%
#it will just show you only 5 records by default
df.head()
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
# 2   3            3         NaN               NaN            NaN
# 3   4            4         NaN               NaN            NaN
# 4   5            5         NaN               NaN            NaN
#
#                            application_process  \
# 0                   Walk in or apply by phone.
# 1           Apply by phone for an appointment.
# 2  Phone for information (403-4300 Ext. 4322).
# 3                              Apply by phone.
# 4                       Phone for information.
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
# 2  Older adults age 55 or over who can benefit fr...
# 3  Parents, children, families with problems of c...
# ...

# %%
# Just for 2 records
df.head(2)
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
#
#                   application_process  \
# 0          Walk in or apply by phone.
# 1  Apply by phone for an appointment.
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
#
#                                          description  \
# 0  A walk-in center for older adults that provide...
# 1  Provides training and job placement to eligibl...
#
#                                          eligibility email  ...  \
# 0  Age 55 or over for most programs, age 60 or ov...   NaN  ...
# 1  Age 55 or over, county resident and willing an...   NaN  ...
#
#   interpretation_services                                           keywords  \
# ...

# %%
# incase we want to see the dataframe from bottom, then it is called as tail
df.tail()
# Out:
#     id  location_id  program_id         accepted_payments  \
# 18  19           19         NaN                       NaN
# 19  20           20         NaN                       NaN
# 20  21           21         NaN                       NaN
# 21  22           22         NaN  Cash, Check, Credit Card
# 22  23           22         NaN                       NaN
#
#            alternate_name                             application_process  \
# 18                    NaN  Call for screening appointment (650-347-3648).
# 19                    NaN                                        Walk in.
# 20                    NaN                 By phone during business hours.
# 21  Fotos para pasaportes               Walk in or apply by phone or mail
# 22                    NaN               Walk in or apply by phone or mail
#
#                                              audience  \
# 18                                                NaN
# 19                                                NaN
# ...

# %%
# incase we want to see the dataframe from bottom, then it is called as tail for only 2 records
df.tail(2)
# Out:
#     id  location_id  program_id         accepted_payments  \
# 21  22           22         NaN  Cash, Check, Credit Card
# 22  23           22         NaN                       NaN
#
#            alternate_name                application_process  \
# 21  Fotos para pasaportes  Walk in or apply by phone or mail
# 22                    NaN  Walk in or apply by phone or mail
#
#                                              audience  \
# 21  Profit and nonprofit businesses, the public, m...
# 22  Second service and nonprofit businesses, the p...
#
#                                           description eligibility  \
# 21  [NOTE THIS IS NOT A REAL SERVICE--THIS IS FOR ...        None
# 22  [NOTE THIS IS NOT A REAL ORGANIZATION--THIS IS...        None
#
#                     email  ...  \
# 21  passports@example.org  ...
# 22                    NaN  ...
#
#                               interpretation_services  \
# 21  We offer 3-way interpretation services over th...
# ...

# %%
#in jupter notebook it is not possible to see all the records, There is a limitation on the console width
#if you want to see some records then use some file system to see it

# %%
# if i want to know what are all the columns are available
df.columns
# Out:
# Index(['id', 'location_id', 'program_id', 'accepted_payments',
#        'alternate_name', 'application_process', 'audience', 'description',
#        'eligibility', 'email', 'fees', 'funding_sources',
#        'interpretation_services', 'keywords', 'languages', 'name',
#        'required_documents', 'service_areas', 'status', 'wait_time', 'website',
#        'taxonomy_ids'],
#       dtype='object')

# %%
# I would like to see the data from just some of the columns
df["email"]
# Out:
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# 5                       NaN
# 6                       NaN
# 7                       NaN
# 8                       NaN
# 9                       NaN
# 10                      NaN
# 11                      NaN
# 12                      NaN
# 13                      NaN
# 14                      NaN
# 15                      NaN
# 16                      NaN
# 17                      NaN
# 18                      NaN
# 19                      NaN
# 20                      NaN
# 21    passports@example.org
# 22                      NaN
# Name: email, dtype: object

# %%
#This is a series
a = df['email']
type(a)
# Out:
# pandas.core.series.Series

# %% [raw]
# # DATAFRAME = Complete tabular structure, something like SQL table
# # SERIES = we know about list, here when ever we try to pull out one single row or one single column
# # pandas is going to represent that as a series, but in a way
# # Series is nothing but it is equivalent to a list
# # Series we can keep multiple hetrogenious informations
# # One row or one column is something which is equivalent to list but it is not called as a list
# # Data frame is a combination of multiple series
# # Series is nothing but another datatype which is available
#
#
# # NOW THERE IS A CONTRADICTION

# %%
# I would like to see the data from just some of the columns
df[["email","keywords"]]
# Out:
#                     email                                           keywords
# 0                     NaN  ADULT PROTECTION AND CARE SERVICES, Meal Sites...
# 1                     NaN  EMPLOYMENT/TRAINING SERVICES, Job Development,...
# 2                     NaN  Geriatric Counseling, Older Adults, Gay, Lesbi...
# 3                     NaN  INDIVIDUAL AND FAMILY DEVELOPMENT SERVICES, Gr...
# 4                     NaN     COMMUNITY SERVICES, Speakers, Automobile Loans
# 5                     NaN  ADULT PROTECTION AND CARE SERVICES, In-Home Su...
# 6                     NaN  ADULT PROTECTION AND CARE SERVICES, Adult Day ...
# 7                     NaN  ADULT PROTECTION AND CARE SERVICES, Meal Sites...
# 8                     NaN  EDUCATION SERVICES, Library, Libraries, Public...
# 9                     NaN  EDUCATION SERVICES, Library, Libraries, Public...
# 10                    NaN  EDUCATION SERVICES, Library, Libraries, Public...
# ...

# %%
b = df[["email","keywords"]]
type(b)
# Out:
# pandas.core.frame.DataFrame

# %%
# I would like to see the data from just some of the columns
df[["name","keywords"]]
# Out:
#                                     name  \
# 0        Fair Oaks Adult Activity Center
# 1       Second Career Employment Program
# 2                 Senior Peer Counseling
# 3               Family Visitation Center
# 4      Economic Self-Sufficiency Program
# 5   Little House Recreational Activities
# 6       Rosener House Adult Day Services
# 7         Meals on Wheels - South County
# 8                       Fair Oaks Branch
# 9                           Main Library
# 10                       Schaberg Branch
# 11                          Project Read
# 12                 Redwood Shores Branch
# 13                    Redwood City Corps
# 14           Adult Rehabilitation Center
# 15                       Sunnyvale Corps
# 16     South San Francisco Citadel Corps
# 17                         Project Smile
# 18         San Mateo Free Medical Clinic
# 19             Service with blank fields
# 20       Service for Admin Test Location
# 21                       Passport Photos
# ...

# %%
type(df[['name']])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # EXCEL SHEET

# %%
# Download zip file from here : https://github.com/finbourne/sample-excel

# %%
# suppose there are multiple sheets inside a sheet
# %ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 408C-821B
#
#  Directory of C:\Users\ashish\Desktop\Ineuron
#
# 05/19/2022  08:20 PM    <DIR>          .
# 05/19/2022  08:20 PM    <DIR>          ..
# 04/07/2022  03:12 PM    <DIR>          .idea
# 05/19/2022  05:22 PM    <DIR>          .ipynb_checkpoints
# 04/10/2022  03:11 PM    <DIR>          __pycache__
# 04/15/2022  09:22 PM                17 abc.txt
# 04/10/2022  01:57 PM                 0 Dict.log
# 05/10/2022  10:32 PM            11,903 glass.data
# 05/18/2022  02:30 PM             8,192 ineuron.db
# 05/17/2022  11:35 AM            12,288 jobdb.db
# 04/15/2022  10:07 PM           197,467 list.log
# 05/19/2022  08:20 PM           161,651 LUSID Excel - Business Agility - Making Simple Changes Quickly & Easily.xlsx
# 05/19/2022  08:20 PM           161,410 LUSID Excel - Maintain a product in multiple currencies and share classes.xlsx
# ...

# %%
#normal import
#By default we can it will readout only the first sheet
pd.read_excel('LUSID Excel - Manage Orders.xlsx')
# Out:
#     Unnamed: 0                                   Unnamed: 1  \
# 0          NaN  This sheet allows you to manage executions:
# 1          NaN                           1. List executions
# 2          NaN                             2. Get execution
# 3          NaN                         3. Upsert executions
# 4          NaN                                          NaN
# ..         ...                                          ...
# 65         NaN                                          NaN
# 66         NaN                                          NaN
# 67         NaN                                          NaN
# 68         NaN                                          NaN
# 69         NaN                                          NaN
#
#            Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0                 NaN        NaN        NaN        NaN        NaN        NaN
# 1                 NaN        NaN        NaN        NaN        NaN        NaN
# ...

# %%
#normal import
#By default we can it will readout only the first sheet, so we can give sheet name
pd.read_excel('LUSID Excel - Manage Orders.xlsx',sheet_name= "Allocations")
# Out:
#     Unnamed: 0                                    Unnamed: 1       Unnamed: 2  \
# 0          NaN  This sheet allows you to manage Allocations:              NaN
# 1          NaN                            1. ListAllocations              NaN
# 2          NaN                              2. GetAllocation              NaN
# 3          NaN                          3. UpsertAllocations              NaN
# 4          NaN                                           NaN              NaN
# ..         ...                                           ...              ...
# 60         NaN                                           NaN              NaN
# 61         NaN                                           NaN              NaN
# 62         NaN                                           NaN             Code
# 63         NaN                                           NaN  MyAllocation001
# 64         NaN                                           NaN  MyAllocation002
#
# ...

# %%
df = pd.read_excel('LUSID Excel - Manage Orders.xlsx')

# %%
# In order to check all the sheet names which are available
df = pd.ExcelFile('LUSID Excel - Manage Orders.xlsx')

# %%
df.sheet_names
# Out:
# ['Executions', 'Orders', 'Allocations', 'Placements', 'Blocks']

# %%
# To get data from all the sheets
for i in df.sheet_names:
    df = pd.read_excel('LUSID Excel - Manage Orders.xlsx', sheet_name= i)

# %%
df
# Out:
#     Unnamed: 0                               Unnamed: 1  \
# 0          NaN  This sheet allows you to manage Blocks:
# 1          NaN                            1. ListBlocks
# 2          NaN                              2. GetBlock
# 3          NaN                          3. UpsertBlocks
# 4          NaN                                      NaN
# 5          NaN                                      NaN
# 6          NaN                                      NaN
# 7          NaN                                      NaN
# 8          NaN                  1. Get a list of blocks
# 9          NaN                                      NaN
# 10         NaN                                    asAt:
# 11         NaN                                      NaN
# 12         NaN                                  filter:
# 13         NaN                                      NaN
# 14         NaN                            propertyKeys:
# 15         NaN                                      NaN
# ...

# %%
# We cannot do that on csv

# %% [markdown]
# # suppose data is available over github
# # Importing data from github

# %%
# always copy raw which is present in the github to copy the entire raw file here
pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
