# %%
# As a data scientist we use a lot to understand this to find patterns etc etc

# %%
#There are certain graphs which are used to represent a certain dataset

# %%
#How i will be able to plot a pattern of the dataset

# %%
#Importing Libraries
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
#Creating a dataset

# %%
df = pd.DataFrame(np.random.randn(1000),columns=['data']) # This is for normal distribution

# %%
#Can you explain me a pattern on the basis of indexes

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.randn(1000),columns=['data'], index = pd.date_range('2022/03/26',periods=1000)) # This is for normal distribution

# %%
df
# Out:
#                 data
# 2022-03-26 -0.008634
# 2022-03-27 -0.555078
# 2022-03-28  0.428803
# 2022-03-29 -0.627378
# 2022-03-30 -0.313653
# ...              ...
# 2024-12-15  0.068879
# 2024-12-16 -0.633736
# 2024-12-17  0.221565
# 2024-12-18 -1.567374
# 2024-12-19 -1.623202
#
# [1000 rows x 1 columns]

# %%
df.plot() #This is similar to stock market graph
# Out:
# <AxesSubplot:>

# %%
#To stretch the graph
df.plot(figsize = (20,10))
# Out:
# <AxesSubplot:>

# %%
Data = pd.read_csv("https://raw.githubusercontent.com/venky14/Machine-Learning-with-Iris-Dataset/master/Iris.csv")

# %%
Data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
Data.plot(figsize = (20,10))
# Out:
# <AxesSubplot:>

# %%
Data = Data.drop("Id",axis=1)

# %%
Data.plot(figsize = (20,10))
# Out:
# <AxesSubplot:>

# %%
Data.plot(kind = 'bar',figsize = (20,10))
# Out:
# <AxesSubplot:>

# %%
Data[5:11].plot(kind = 'bar',figsize = (20,10))
# Out:
# <AxesSubplot:>

# %%
Data.iloc[5:11]
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 5             5.4           3.9            1.7           0.4  Iris-setosa
# 6             4.6           3.4            1.4           0.3  Iris-setosa
# 7             5.0           3.4            1.5           0.2  Iris-setosa
# 8             4.4           2.9            1.4           0.2  Iris-setosa
# 9             4.9           3.1            1.5           0.1  Iris-setosa
# 10            5.4           3.7            1.5           0.2  Iris-setosa

# %%
#graph for one single row
Data.iloc[[5]].plot(kind = 'bar', figsize  = (20,10))
# Out:
# <AxesSubplot:>

# %%
#graph for one single row
Data.iloc[[5]].plot(kind = 'barh', figsize  = (20,10))
# Out:
# <AxesSubplot:>

# %%
Data[5:11].plot(kind = 'barh',figsize = (20,10))
# Out:
# <AxesSubplot:>

# %%
#It gives us a frequency, This is giving us a meaning
#it will always try to show you frequency
Data.plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
Data
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
#This tells us howmanny datasets are available in that range
#This can also be called as a bucket
Data['SepalLengthCm'].plot(kind ='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
Data['SepalLengthCm'].plot(kind ='hist', orientation = 'horizontal')
# Out:
# <AxesSubplot:xlabel='Frequency'>

# %%
Data.hist(figsize=(20,10))
# Out:
# array([[<AxesSubplot:title={'center':'SepalLengthCm'}>,
#         <AxesSubplot:title={'center':'SepalWidthCm'}>],
#        [<AxesSubplot:title={'center':'PetalLengthCm'}>,
#         <AxesSubplot:title={'center':'PetalWidthCm'}>]], dtype=object)

# %%
Data.hist(figsize=(20,10),color = 'b')
# Out:
# array([[<AxesSubplot:title={'center':'SepalLengthCm'}>,
#         <AxesSubplot:title={'center':'SepalWidthCm'}>],
#        [<AxesSubplot:title={'center':'PetalLengthCm'}>,
#         <AxesSubplot:title={'center':'PetalWidthCm'}>]], dtype=object)

# %%
Data.hist(figsize=(20,10),color = 'r', alpha = .5)
# Out:
# array([[<AxesSubplot:title={'center':'SepalLengthCm'}>,
#         <AxesSubplot:title={'center':'SepalWidthCm'}>],
#        [<AxesSubplot:title={'center':'PetalLengthCm'}>,
#         <AxesSubplot:title={'center':'PetalWidthCm'}>]], dtype=object)

# %%
Data.hist(figsize=(20,10),color = 'r', alpha = .9)
# Out:
# array([[<AxesSubplot:title={'center':'SepalLengthCm'}>,
#         <AxesSubplot:title={'center':'SepalWidthCm'}>],
#        [<AxesSubplot:title={'center':'PetalLengthCm'}>,
#         <AxesSubplot:title={'center':'PetalWidthCm'}>]], dtype=object)

# %%
#BoXPLOT

# %%
Data.plot(kind = 'box', figsize = (20,10))
# Out:
# <AxesSubplot:>

# %%
Data.plot(kind = 'box', figsize = (20,10),color = {'boxes': 'g','whiskers' : 'r'})
# Out:
# <AxesSubplot:>

# %%
Data.plot(kind = 'box', figsize = (20,10),color = {'boxes': 'g','whiskers' : 'r'},vert = False)
# Out:
# <AxesSubplot:>

# %%
#Interpretation - Here for PetalLengthCm  we can say that we have majority dataset in between 25% to 50%, similarly there
#is majority of the dataset inbetween 75th Percentile to max

# %%
#How to find median, first sort the values in ascending order and then find the mid point
#Mean = its the Average
#Mode = Frequency

# %%
#IQR - Interquantile Range
#Q3 - Q1 = IQR or interquantile range, what is the value of dataset available inbetween
#Recording 1 hour 32 mins and forward

# %%
#max
#Q3 = 75%
#Median = Half = Q2 = 50%
#Q1 = 25%
#min

# %%
# standard practise 1.5
#Calculation for minimum = Q1 - 1.5(IQR)
#Calculation for max = Q3 + 1.5(IQR)

# %%
Data.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
6.40-5.10
# Out:
# 1.3000000000000007

# %%
#AREA Graph

# %%
Data.plot(kind = 'area',figsize = (20,10))
# Out:
# <AxesSubplot:>

# %%
Data.plot(kind = 'area',figsize = (20,10),alpha = .4)
# Out:
# <AxesSubplot:>

# %%
#It is overlapping
Data.plot(kind = 'area',figsize = (20,10),alpha = .4,stacked = False)
# Out:
# <AxesSubplot:>

# %%
Data
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
#Scatter plot always takes 2 axis, Suppose we have to do a comparision, suppose i have to findout if there is any relationship
#Between sepal length and sepal width, or sepal length or petal length
Data.plot.scatter(x = 'SepalLengthCm', y='PetalLengthCm')

#INT
#Sepal length is increasing as the petallength is increasing
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %%
#it is trying to set the color on the basis of a particular column
Data.plot.scatter(x = 'SepalLengthCm', y='PetalWidthCm',c='SepalWidthCm')
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='PetalWidthCm'>

# %%
#it is trying to set the color on the basis of a particular column
Data.plot.scatter(x = 'SepalLengthCm', y='PetalWidthCm',c='SepalWidthCm',s = 600)
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='PetalWidthCm'>

# %%
#it is trying to set the color on the basis of a particular column , Experiment, These *500 is also called as pixel
Data.plot.scatter(x = 'SepalLengthCm', y='PetalWidthCm',c='SepalWidthCm',s = Data['PetalLengthCm']*500)
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='PetalWidthCm'>

# %%
#it is trying to set the color on the basis of a particular column , Experiment, These *500 is also called as pixel
Data.plot.hexbin(x = 'SepalLengthCm', y='PetalWidthCm',gridsize=10)
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='PetalWidthCm'>

# %%
Data1 = Data.drop(columns='Species').iloc[0]
#we are dropping this column as it was a categoricaL Column

# %% [markdown]
# # Pie Plot

# %%
Data1.plot(kind = 'pie')
# Out:
# <AxesSubplot:ylabel='0'>

# %%
# !pip install plotly

# %%
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.2.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
Data.iplot()
# Out:
# <div>                            <div id="d92ac230-a91a-4ace-9313-8bc61ce61bda" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
# Click on produce with plotly

# %%
Data.iplot(x='SepalLengthCm',y= 'PetalLengthCm',mode = 'markers')
# Out:
# <div>                            <div id="bcd6398b-2dcc-49a8-9a08-f46f3fa4460c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
Data.iplot(x='SepalLengthCm',y= 'PetalLengthCm',mode = 'markers',kind= 'scatter')
# Out:
# <div>                            <div id="bf349736-0324-4e68-9370-cb2496170827" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
Data.iplot(kind = "scatter",mode = 'markers',size = 10)
# Out:
# <div>                            <div id="d3ea7aae-c038-4cfb-9e81-9b5aa193789e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
Data.iplot(kind = 'bubble',x = 'SepalLengthCm',y = 'PetalLengthCm',size = 'SepalWidthCm')
# Out:
# <div>                            <div id="0b806bf0-5fa0-4514-953f-5dba3b0c9560" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
Data.scatter_matrix()
# Out:
# <div>                            <div id="c6d3e7f3-1fa0-40f5-b20f-2dab79cb4e60" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
Data
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
Data.head().iplot(kind = 'scatter3d', x = 'SepalLengthCm',y = 'SepalWidthCm',z = 'PetalLengthCm')
# Out:
# <div>                            <div id="8e8000d4-6980-49bd-ba11-7b7c86a04a1b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
Data.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
Data.iplot(kind = 'scatter3d', x = 'SepalLengthCm',y = 'SepalWidthCm',z = 'PetalLengthCm')
# Out:
# <div>                            <div id="67bcc8e5-743d-406b-a48b-0bea3798b877" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
Data.iplot(kind = 'bubble3d', x = 'SepalLengthCm',y = 'SepalWidthCm',z = 'PetalLengthCm',size = 'PetalWidthCm')
# Out:
# <div>                            <div id="54d8d7d9-b6db-4924-9300-13a8573d6f72" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [raw]
# # Assignment
#
# Try to explore map graph and try to show and example (2-3)
