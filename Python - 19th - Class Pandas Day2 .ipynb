# %%
# Pandas is a very useful and important library which we will use from the very first day to the very last day
# Data Manipulation or data how we can try to read out
# Can you extract this tabular dataset so that i can run my analysis., i will be able to do my data manipulation operations
# Data extraction/transformation operations, Data irrigation operations
# Yes i can do that, i can atleast give it a try

# %%
import pandas as pd

# %%
df = pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')

# %%
df
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
#there are 675 rows and 30 columns available

# %%
#We want that in tabular format, readable format

# %%
type(df)
# Out:
# list

# %%
len(df)
# Out:
# 1

# %%
df[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
type(df[0])
# Out:
# pandas.core.frame.DataFrame

# %%
#here what we can say is in a list at the 0th index my values are available as a Dataframe

# %%
# Read html:
# Limitations of Read_html:
# It will always try to scrap a tabular format of the data
# if dataset is not available into tabular format it will not try to scrape it
# if the dataset is available in tr and th tag only then it will be able to extract a data
# this is what read html does
# But it is possible to scrape any data which is available in your screen
# Including images

# %%
# why are we scraping a website?
# whenever we build a model, sometimes what happens is the internal source of data will not be sufficient enough
# so we may have to aquire a data from some external source or maybe from some open source or maybe from some of the website
# in that case we need to know for sure how to do scrapping

# %%
# It is important to acquire a data from a third party data or from somewhere else
# There are chances that we might have many tables on the website

# %%
df1 = df[0]

# %%
df1.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
df1.head(3)
# Out:
#   Rk        Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1    Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79  222
# 1  2  Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9   19
# 2  3  Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199  324
#
#    TRB AST STL BLK TOV   PF  PTS
# 0  301  68  27  22  60  147  398
# 1   28  16  16   7  14   24   94
# 2  523  66  38  86  99  222  537
#
# [3 rows x 30 columns]

# %%
df1.tail(3)
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST STL BLK TOV   PF  PTS
# 672  114  166   38  38   8  42   56  386
# 673  265  362  100  34  49  62  156  472
# 674  319  465  113  18  52  76  205  833
#
# [3 rows x 30 columns]

# %%
df1.dtypes
# Out:
# Rk        object
# Player    object
# Pos       object
# Age       object
# Tm        object
# G         object
# GS        object
# MP        object
# FG        object
# FGA       object
# FG%       object
# 3P        object
# 3PA       object
# 3P%       object
# 2P        object
# 2PA       object
# 2P%       object
# eFG%      object
# FT        object
# FTA       object
# FT%       object
# ORB       object
# DRB       object
# TRB       object
# AST       object
# STL       object
# BLK       object
# TOV       object
# PF        object
# PTS       object
# dtype: object

# %%
# Selecting specific columns - Selection operation
df1[["Age","GS"]]
# Out:
#     Age  GS
# 0    24  22
# 1    20   0
# 2    21  67
# 3    28   0
# 4    29  72
# ..   ..  ..
# 670  26  68
# 671  26  48
# 672  26  20
# 673  22  45
# 674  25  59
#
# [675 rows x 2 columns]

# %%
df1
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
#Inorder to save the data
df1.to_csv('nba.csv')

# %%
# %ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 408C-821B
#
#  Directory of C:\Users\ashish\Desktop\Ineuron
#
# 05/20/2022  10:30 PM    <DIR>          .
# 05/20/2022  10:30 PM    <DIR>          ..
# 04/07/2022  03:12 PM    <DIR>          .idea
# 05/20/2022  09:11 PM    <DIR>          .ipynb_checkpoints
# 04/10/2022  03:11 PM    <DIR>          __pycache__
# 04/15/2022  09:22 PM                17 abc.txt
# 05/20/2022  07:09 AM           628,633 carbon_nanotubes.csv
# 05/20/2022  09:48 PM             5,658 cricket.csv
# 04/10/2022  01:57 PM                 0 Dict.log
# 05/10/2022  10:32 PM            11,903 glass.data
# 05/18/2022  02:30 PM             8,192 ineuron.db
# 05/17/2022  11:35 AM            12,288 jobdb.db
# 04/15/2022  10:07 PM           197,467 list.log
# 05/19/2022  08:20 PM           161,651 LUSID Excel - Business Agility - Making Simple Changes Quickly & Easily.xlsx
# ...

# %%
#Inorder to save the data, storing without no index or no header
df1.to_csv('nba1.csv',index= False)

# %%
#Inorder to save the data, storing without no index or no header
df1.to_csv('nba2.csv',header= False)

# %%
l = pd.read_html('https://stats.espncricinfo.com/ci/engine/records/averages/batting.html?class=3;id=6;type=team')

# %%
len(l)
# Out:
# 3

# %%
l[0].to_csv('cricket.csv',index= False)

# %%
d = """{"name" : "Ashish Roy",
"emailid" : "ashishroyofficial@gmail.com",
"tech" : ["ML","DL","CV","NLP","RL","BD","DA"],
"platform" : ["techneuron","kidsneuron","ineuronz"]
}"""

# %%
# how to convert the data into dataframe
# this is a data which is available into a dictionary format
import json

# %%
# use json viewer on google

# %%
#java script object notation format

# %%
result = json.loads(d)

# %%
result
# Out:
# {'name': 'Ashish Roy',
#  'emailid': 'ashishroyofficial@gmail.com',
#  'tech': ['ML', 'DL', 'CV', 'NLP', 'RL', 'BD', 'DA'],
#  'platform': ['techneuron', 'kidsneuron', 'ineuronz']}

# %%
type(result)
# Out:
# dict

# %%
#Walk around
# why am  i not able to convert it?

# %%
d = """{"name" : "Ashish Roy",
"emailid" : "ashishroyofficial@gmail.com",
"tech" : ["ML","DL","CV"],
"platform" : ["techneuron","kidsneuron","ineuronz"]
}"""

# %%
result = json.loads(d)

# %%
pd.DataFrame(result)
# Out:
#          name                      emailid tech    platform
# 0  Ashish Roy  ashishroyofficial@gmail.com   ML  techneuron
# 1  Ashish Roy  ashishroyofficial@gmail.com   DL  kidsneuron
# 2  Ashish Roy  ashishroyofficial@gmail.com   CV    ineuronz

# %%
#Here we have the same array length so it worked
#There was a mismatch in between
# incase we  have a different length it wont work
# Recording 1 hour 20 minutes (27th feb)

# %%
#Another example
d = """{"name" : "Ashish Roy",
"emailid" : "ashishroyofficial@gmail.com",
"tech" : ["ML","DL","CV"],
"platform" : "techneuron"
}"""

# %%
result = json.loads(d)

# %%
pd.DataFrame(result)
# Out:
#          name                      emailid tech    platform
# 0  Ashish Roy  ashishroyofficial@gmail.com   ML  techneuron
# 1  Ashish Roy  ashishroyofficial@gmail.com   DL  techneuron
# 2  Ashish Roy  ashishroyofficial@gmail.com   CV  techneuron

# %%
#another example
d = """{"name" : "Ashish Roy",
"emailid" : "ashishroyofficial@gmail.com",
"tech" : ["ML","DL","CV","NLP","RL","BD","DA"],
"platform" : ["techneuron","kidsneuron","ineuronz"]
}"""

# %%
result = json.loads(d)

# %%
#This will return list
#String to dataframe we cannot convert, but when we have something into list format and we are planning to convert into DB we can
pd.DataFrame(result['tech']) # this is a list inside json file
# Out:
#      0
# 0   ML
# 1   DL
# 2   CV
# 3  NLP
# 4   RL
# 5   BD
# 6   DA

# %%
# Recording 1 hour 29 mins

# %%
d = {"packetType":"D","data":{"checkEngineLightFlag":"F","batteryVoltageStableTime":0,"batteryVoltageStable":"0","batteryVoltageOff":"12.42","batteryCrankParamTN":"-0.08","batteryCrankParamVN":"0.00","batteryCrankParamTP":"-0.08","batteryCrankParamVP":"0.00","batteryCrankParamTT":"-0.00008","batteryCrankParamV0":"0.00","batteryVoltageMaxOn":"13.05","batteryVoltageMinOn":"12.97","batteryVoltageMaxOff":"12.46","batteryVoltageMinOff":"12.36","batteryVoltageOnAverage":"13.02","engineLoadMax":"84","engineLoadAverage":"39.98","rpmMax":"3487","rpmAverage":"1431.29","gpsSpeedAverage":"21.99","vssMax":"53.44","vssAverage":"23.06","tcuTemperatureMin":"82.40","tcuTemperatureMax":"109.40","tcuTemperatureAverage":"104.87","coolantMin":"158.00","coolantMax":"188.60","coolantAverage":"180.20","packetStartLocal":1508143346000,"tripStartLocal":1508143346000,"milIndicator":"F","monitorsNotReady":0,"imei":"60DF5417","gatewayTs":1515613306592,"diagnosticTroubleCodeData":[],"diagnosticPidData":[[64768,47,100],[64768,1,517376],[64800,1,262144],[64768,5,125]]},"header":{"iwrapVer":"1.9.20","sourceSystem":"CDP","configVer":"1.1","oemName":"HUM","unitType":0,"cpVer":"7.50.1.9","igpsVer":"1.3.7","messageType":"Notification","pomVer":"1.0","headerVer":"V6","timestamp":0,"deviceType":"InDrive","visorVer":"1.4.35","transactionId":"53098471-7787-4160-94b3-cd69dcc70416","deviceSerialNo":"60DF5417","subOrganization":"HUM","organization":"HUM","imei":"60DF5417","operation":"Notification"}}

# %%
d1 = d["data"]

# %%
d1
# Out:
# {'checkEngineLightFlag': 'F',
#  'batteryVoltageStableTime': 0,
#  'batteryVoltageStable': '0',
#  'batteryVoltageOff': '12.42',
#  'batteryCrankParamTN': '-0.08',
#  'batteryCrankParamVN': '0.00',
#  'batteryCrankParamTP': '-0.08',
#  'batteryCrankParamVP': '0.00',
#  'batteryCrankParamTT': '-0.00008',
#  'batteryCrankParamV0': '0.00',
#  'batteryVoltageMaxOn': '13.05',
#  'batteryVoltageMinOn': '12.97',
#  'batteryVoltageMaxOff': '12.46',
#  'batteryVoltageMinOff': '12.36',
#  'batteryVoltageOnAverage': '13.02',
#  'engineLoadMax': '84',
#  'engineLoadAverage': '39.98',
#  'rpmMax': '3487',
#  'rpmAverage': '1431.29',
#  'gpsSpeedAverage': '21.99',
#  'vssMax': '53.44',
#  'vssAverage': '23.06',
#  'tcuTemperatureMin': '82.40',
#  'tcuTemperatureMax': '109.40',
#  'tcuTemperatureAverage': '104.87',
#  'coolantMin': '158.00',
#  'coolantMax': '188.60',
#  'coolantAverage': '180.20',
#  'packetStartLocal': 1508143346000,
#  'tripStartLocal': 1508143346000,
#  'milIndicator': 'F',
# ...

# %%
del d1['diagnosticTroubleCodeData'] #we are removing this as this consists of null inside it

# %%
d1
# Out:
# {'checkEngineLightFlag': 'F',
#  'batteryVoltageStableTime': 0,
#  'batteryVoltageStable': '0',
#  'batteryVoltageOff': '12.42',
#  'batteryCrankParamTN': '-0.08',
#  'batteryCrankParamVN': '0.00',
#  'batteryCrankParamTP': '-0.08',
#  'batteryCrankParamVP': '0.00',
#  'batteryCrankParamTT': '-0.00008',
#  'batteryCrankParamV0': '0.00',
#  'batteryVoltageMaxOn': '13.05',
#  'batteryVoltageMinOn': '12.97',
#  'batteryVoltageMaxOff': '12.46',
#  'batteryVoltageMinOff': '12.36',
#  'batteryVoltageOnAverage': '13.02',
#  'engineLoadMax': '84',
#  'engineLoadAverage': '39.98',
#  'rpmMax': '3487',
#  'rpmAverage': '1431.29',
#  'gpsSpeedAverage': '21.99',
#  'vssMax': '53.44',
#  'vssAverage': '23.06',
#  'tcuTemperatureMin': '82.40',
#  'tcuTemperatureMax': '109.40',
#  'tcuTemperatureAverage': '104.87',
#  'coolantMin': '158.00',
#  'coolantMax': '188.60',
#  'coolantAverage': '180.20',
#  'packetStartLocal': 1508143346000,
#  'tripStartLocal': 1508143346000,
#  'milIndicator': 'F',
# ...

# %%
pd.DataFrame(d1)
# Out:
#   checkEngineLightFlag  batteryVoltageStableTime batteryVoltageStable  \
# 0                    F                         0                    0
# 1                    F                         0                    0
# 2                    F                         0                    0
# 3                    F                         0                    0
#
#   batteryVoltageOff batteryCrankParamTN batteryCrankParamVN  \
# 0             12.42               -0.08                0.00
# 1             12.42               -0.08                0.00
# 2             12.42               -0.08                0.00
# 3             12.42               -0.08                0.00
#
#   batteryCrankParamTP batteryCrankParamVP batteryCrankParamTT  \
# 0               -0.08                0.00            -0.00008
# 1               -0.08                0.00            -0.00008
# 2               -0.08                0.00            -0.00008
# ...

# %%
url = "https://api.github.com/repos/pandas-dev/pandas/issues"

# %%
pd.read_json(url)
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
# 2nd Alternative:

# %%
#First load raw json

# %%
# Request method
import requests

# %%
data = requests.get(url) # it is a successful req

# %%
data1 = data.json()

# %%
data1
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47076',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47076/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47076/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47076/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/47076',
#   'id': 1243412992,
#   'node_id': 'PR_kwDOAA0YD844NFgU',
#   'number': 47076,
#   'title': 'ENH: liboffsets support non-nano',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
# ...

# %%
len(data1) #30 unique dictionaries which are available
# Out:
# 30

# %%
data1[1]['user']['id']
# Out:
# 6618166

# %%
for i in range(len(data1)):
    print(data1[i]['user']['id'])
# Out:
# 8078968
# 6618166
# 1020496
# 36327192
# 13159005
# 23625371
# 1020496
# 6320308
# 6320308
# 29632816
# 17395686
# 16463246
# 8284922
# 15721311
# 32496804
# 6618166
# 8078968
# 24256554
# 1508012
# 8284922
# 6618166
# 56446640
# 10647082
# 47963215
# 44754681
# 36619387
# 6054951
# 8078968
# 5629061
# 50434302

# %%
# represent it into tabular format

# %%
data1
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47076',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47076/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47076/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47076/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/47076',
#   'id': 1243412992,
#   'node_id': 'PR_kwDOAA0YD844NFgU',
#   'number': 47076,
#   'title': 'ENH: liboffsets support non-nano',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
# ...

# %%
pd.DataFrame(data1, columns=['id','url','repository_url','labels_url','user']) #inseide user there is another dictionary
# Out:
#             id                                                url  \
# 0   1243412992  https://api.github.com/repos/pandas-dev/pandas...
# 1   1243374107  https://api.github.com/repos/pandas-dev/pandas...
# 2   1243359572  https://api.github.com/repos/pandas-dev/pandas...
# 3   1243086499  https://api.github.com/repos/pandas-dev/pandas...
# 4   1242986429  https://api.github.com/repos/pandas-dev/pandas...
# 5   1242983125  https://api.github.com/repos/pandas-dev/pandas...
# 6   1242852588  https://api.github.com/repos/pandas-dev/pandas...
# 7   1242351460  https://api.github.com/repos/pandas-dev/pandas...
# 8   1242299667  https://api.github.com/repos/pandas-dev/pandas...
# 9   1241932207  https://api.github.com/repos/pandas-dev/pandas...
# 10  1240509942  https://api.github.com/repos/pandas-dev/pandas...
# 11  1239889808  https://api.github.com/repos/pandas-dev/pandas...
# 12  1239370132  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
#df2.to_csv('json_res.csv')
